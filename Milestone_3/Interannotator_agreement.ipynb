# %% [markdown]
# ## Interannotator Agreement

# %%
import nltk
from nltk.metrics.agreement import AnnotationTask

# %%
sentence = ["Jack","fell","down","and","Jill","came","tumbling","after"]
#my code here
annotations = {"C1":["Person","None","None","None","None","None","None","None"],
               "C2":["Person","None","None","None","Person","None","None","None"],
               "C3":["Person","None","None","None","Person","None","None","Person"]}
#my code here

# %%
def convert_to_tuples(annotations_list):
    # We need to have (Annotator, Sentence, Yes/No) triples
    triple_list = []
    for (index, (workers_list, label_list)) in enumerate(annotations_list):
        for i in range(len(label_list)):
            triple_list.append((workers_list[i], str(index),label_list[i]))
    
    return triple_list

# %%
import pandas as pd

annotations_df = pd.read_csv("annotations.csv")
hit_id_annotation_df = annotations_df.iloc[:,[0,15,29]]
hit_id_annotation_df = hit_id_annotation_df.rename(columns={"Answer.grammar-correction.label": "Label"})
hit_id_annotation_df = hit_id_annotation_df.groupby('HITId').agg(lambda x: x.tolist())
hit_id_annotation_df.values.tolist()
# Out:
# [[['A2UNQ8YQL05X7T', 'A13XNZBCRSEGGY', 'A2PQN6EIDHNJWJ'],
#   ['Yes', 'No', 'Yes']],
#  [['A3L6JLT39UBMCD', 'AJ9O2ZA0E8UDZ', 'A1P8G437YE33GL'], ['Yes', 'Yes', 'No']],
#  [['A1BPX78NLNLI9B', 'A10042UW3Q59GF', 'AJ9O2ZA0E8UDZ'], ['No', 'Yes', 'Yes']],
#  [['A19Y8QDS9ABVD4', 'A13HAGXAAV0R3W', 'A10042UW3Q59GF'],
#   ['Yes', 'No', 'Yes']],
#  [['A3EB5G62854MAJ', 'A13XNZBCRSEGGY', 'A1P8G437YE33GL'],
#   ['Yes', 'No', 'Yes']],
#  [['A3EB5G62854MAJ', 'A1KQ4XZM996XWW', 'AF8OCFNA5KE8A'], ['Yes', 'Yes', 'No']],
#  [['AJ9O2ZA0E8UDZ', 'A1EF3SB1XTBETJ', 'A2F0X4LN9N4O4C'],
#   ['Yes', 'Yes', 'Yes']],
#  [['A2ZLJQWCM8KU36', 'A2NI0G1DKQJ08H', 'AWS8VZX8K72NU'],
#   ['Yes', 'Yes', 'Yes']],
#  [['A1JKZ6D8L1A8J1', 'AJ9O2ZA0E8UDZ', 'A3FOC1PCYZ0VT1'],
#   ['Yes', 'Yes', 'Yes']],
#  [['A7O1CG4QYBEIP', 'AKSLU0C30G3JT', 'AD01UNQ1IAKCP'], ['Yes', 'No', 'Yes']],
#  [['A10042UW3Q59GF', 'ADP1QUGXHGJRS', 'A20CVITAYVBNBU'], ['Yes', 'No', 'No']],
# ...

# %%
triples = convert_to_tuples(hit_id_annotation_df.values.tolist())

for i, triple in enumerate(triples):
    triple = ("annotator"+str(i % 3), triple[1], triple[2])
    triples[i] = triple

triples
# Out:
# [('annotator0', '0', 'Yes'),
#  ('annotator1', '0', 'No'),
#  ('annotator2', '0', 'Yes'),
#  ('annotator0', '1', 'Yes'),
#  ('annotator1', '1', 'Yes'),
#  ('annotator2', '1', 'No'),
#  ('annotator0', '2', 'No'),
#  ('annotator1', '2', 'Yes'),
#  ('annotator2', '2', 'Yes'),
#  ('annotator0', '3', 'Yes'),
#  ('annotator1', '3', 'No'),
#  ('annotator2', '3', 'Yes'),
#  ('annotator0', '4', 'Yes'),
#  ('annotator1', '4', 'No'),
#  ('annotator2', '4', 'Yes'),
#  ('annotator0', '5', 'Yes'),
#  ('annotator1', '5', 'Yes'),
#  ('annotator2', '5', 'No'),
#  ('annotator0', '6', 'Yes'),
#  ('annotator1', '6', 'Yes'),
#  ('annotator2', '6', 'Yes'),
#  ('annotator0', '7', 'Yes'),
#  ('annotator1', '7', 'Yes'),
#  ('annotator2', '7', 'Yes'),
#  ('annotator0', '8', 'Yes'),
#  ('annotator1', '8', 'Yes'),
#  ('annotator2', '8', 'Yes'),
#  ('annotator0', '9', 'Yes'),
#  ('annotator1', '9', 'No'),
#  ('annotator2', '9', 'Yes'),
#  ('annotator0', '10', 'Yes'),
#  ('annotator1', '10', 'No'),
# ...

# %%
triples_clean = [('C1', 'Jack', 'Person'),
 ('C1', 'fell', 'None'),
 ('C1', 'down', 'None'),
 ('C1', 'and', 'None'),
 ('C1', 'Jill', 'None'),
 ('C1', 'came', 'None'),
 ('C1', 'tumbling', 'None'),
 ('C1', 'after', 'None'),
 ('C2', 'Jack', 'Person'),
 ('C2', 'fell', 'None'),
 ('C2', 'down', 'None'),
 ('C2', 'and', 'None'),
 ('C2', 'Jill', 'Person'),
 ('C2', 'came', 'None'),
 ('C2', 'tumbling', 'None'),
 ('C2', 'after', 'None'),
 ('C3', 'Jack', 'Person'),
 ('C3', 'fell', 'None'),
 ('C3', 'down', 'None'),
 ('C3', 'and', 'None'),
 ('C3', 'Jill', 'Person'),
 ('C3', 'came', 'None'),
 ('C3', 'tumbling', 'None'),
 ('C3', 'after', 'Person')]

# %%
annotation_task = AnnotationTask(triples)

print(annotation_task.avg_Ao())
print(annotation_task.pi())
# Out:
# 0.5757575757575758
# 0.10504105963138553

# %% [markdown]
# Identify an appropriate interannotator agreement measure based on the nature of your annotation (justify your choice!), calculate interannotator agreement, and discuss whether you think your annotation is reliable or not. If your annotator agreement is low, please talk about why it is low, and what you might do to improve it. Include a link to any code you used to calculate interannotator agreement. Note if your agreement is low and it appears that it is low because you didn't take steps to ensure quality, you will lose points here even if the results of the study are accurate.
